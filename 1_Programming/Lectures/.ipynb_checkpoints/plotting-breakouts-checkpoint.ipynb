# %% [markdown]
# # Plotting breakouts

# %% [markdown]
# ### Question 1 - Simple plot
#
# **WRITE** the sin wave code from the slide into the cell below and create a plot...
#
#   1. Can you change the size?
#   2. Can you change the DPI?

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
plt.style.use('classic')

# %%
## initialize the axes
fig = plt.figure(figsize=(10,5), dpi=400)
ax = fig.add_subplot(1,1,1)

## format axes
ax.set_ylabel('volts')
ax.set_title('a sine wave')

t = np.arange(0.0, 1.0, 0.01)
s = np.sin(2*np.pi*t)
s[3] = np.nan
line, = ax.plot(t, s, color='blue', lw=2)

# %% [markdown]
# ### Question 2 - Create a plot
#
#   1. Go to the [Matplotlib gallery](http://matplotlib.org/gallery.html)
#   2. Select a plot that looks reasonably simple (i.e. barh_demo, fill_demo, hist_demo)
#   3. Make it work in the empty space below
#   4. Save it to disk
#   5. Did you use the pylab/artist interface?
#   6. [EXTRA] If you have time can you rewrite it using the other interface?

# %%
x = np.linspace(0, 1, 300)
y = np.sin(10 * np.pi * x) * np.exp(-10 * x)

fig, ax = plt.subplots()

ax.fill(x, y, zorder=10)
ax.grid(True, zorder=5)

# %% [markdown]
# ### Question 3 - Axes
#
# Now that you know about axes.  Create three subplots as follows.
#
# ```
# ## Hints
# x = np.random.normal(100)
# bins = 20
# ...
# ax1.hist(x, normed=True,color="#9999FF",bins=bins,histtype='stepfilled')
# ...
# ```

# %%
from IPython.display import Image
Image(filename='breakout-1.png')

# %%
x = np.random.normal(1, size=100)
bins = 20
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,1,2)

for ax in [ax1,ax2,ax3]:
    ax.hist(x, normed=True,color="#9999FF",bins=bins,histtype='stepfilled')
# Out:
# (array([ 0.07821356,  0.        ,  0.        ,  0.11732035,  0.03910678,
#          0.23464069,  0.4301746 ,  0.31285425,  0.4301746 ,  0.27374747,
#          0.39106782,  0.27374747,  0.27374747,  0.31285425,  0.23464069,
#          0.11732035,  0.03910678,  0.15642713,  0.        ,  0.19553391]),
#  array([-1.80034488, -1.54463476, -1.28892463, -1.03321451, -0.77750439,
#         -0.52179426, -0.26608414, -0.01037402,  0.24533611,  0.50104623,
#          0.75675635,  1.01246647,  1.2681766 ,  1.52388672,  1.77959684,
#          2.03530697,  2.29101709,  2.54672721,  2.80243734,  3.05814746,
#          3.31385758]),
#  <a list of 1 Patch objects>)

# %%
x
# Out:
# 98.90719108253013
